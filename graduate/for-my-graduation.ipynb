# %%
# !git clone https://github.com/rari458/Projects.git /kaggle/temp/repo
# %cd /kaggle/temp/repo/graduate
# %env OUTDIR=/kaggle/working
# %env REQUIRE_GPU=1

# %%
import os
os.environ["REQUIRE_GPU"] = "1"
os.environ["OUTDIR"] = "/kaggle/working"

import benchmark_cifar10 as B
B.KINDS = ["muonsam_nomom"]
B.LOGFILE = "/kaggle/working/runlog_nomom_seed0.csv"
B.main()

os.replace("/kaggle/working/benchmark.png", "/kaggle/working/benchmark_nomom_seed0.png")

# %%
# !ls -la /kaggle/working

# %%
# !ls -la /kaggle/working/runlog_nomom_seed0.csv /kaggle/working/benchmark_nomom_seed0.png
